# %%
l = [ 2, 5, 6, 7, 8, 9]

# %%
l[2:6]
# Out:
# [6, 7, 8, 9]

# %%
l[3] = "apple"

# %%
l[0:6]
# Out:
# [2, 5, 6, 'apple', 8, 9]

# %%
l.append(99)

# %%
l
# Out:
# [2, 5, 6, 'apple', 8, 9, 99]

# %%
l2 = [11,22,33,44]

# %%
l.extend(l2)

# %%
l
# Out:
# [2, 5, 6, 'apple', 8, 9, 99, 11, 22, 33, 44]

# %%
l.insert(2, 200)

# %%
l
# Out:
# [2, 5, 200, 6, 'apple', 8, 9, 99, 11, 22, 33, 44]

# %%
l.pop(2)
# Out:
# 200

# %%
l
# Out:
# [2, 5, 6, 'apple', 8, 9, 99, 11, 22, 33, 44]

# %%
l.index(33)
# Out:
# 9

# %%
l.append(5)

# %%
l
# Out:
# [2, 5, 6, 'apple', 8, 9, 99, 11, 22, 33, 44, 5]

# %%
l.count(5)
# Out:
# 2

# %%
l.reverse()

# %%
l
# Out:
# [5, 44, 33, 22, 11, 99, 9, 8, 'apple', 6, 5, 2]

# %%
l.pop(8)
# Out:
# 'apple'

# %%
l
# Out:
# [5, 44, 33, 22, 11, 99, 9, 8, 6, 5, 2]

# %%
l.sort()

# %%
l
# Out:
# [2, 5, 5, 6, 8, 9, 11, 22, 33, 44, 99]

# %%
l3 = [2,4,5,6, [1,2,3,4],8,9,0]

# %%
l3
# Out:
# [2, 4, 5, 6, [1, 2, 3, 4], 8, 9, 0]

# %%
l3[3:6]
# Out:
# [6, [1, 2, 3, 4], 8]

# %%
l3[4]
# Out:
# [1, 2, 3, 4]

# %%
l3[4][3]
# Out:
# 4

# %%
l4 = [1 , 2, 3]

# %%
l5 = [4, 5, 6]

# %%
l4 
l5
# Out:
# [4, 5, 6]

# %%
l4 + l5
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
if 3 in l4:
    print("yes")
# Out:
# yes
