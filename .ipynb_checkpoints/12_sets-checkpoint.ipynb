# %%
a = {}

# %%
type(a)
# Out:
# dict

# %%
emptyset = ()

# %%
type(emptyset)
# Out:
# tuple

# %%
empty_set = set()

# %%
type(empty_set)
# Out:
# set

# %%
a = { 2, 5, 7, 8, 9, 3}

# %%
empty_set =  { 2, 5, 7, 8, 9, 3, 2}

# %%
empty_set
# Out:
# {2, 3, 5, 7, 8, 9}

# %%
unique_numbers = set([2, 5, 7, 4, 9, 2 ,8])

# %%
unique_numbers
# Out:
# {2, 4, 5, 7, 8, 9}

# %%
empty_set.add(99)

# %%
empty_set
# Out:
# {2, 3, 5, 7, 8, 9, 99}

# %%
empty_set= set([33, 66, 77, 2])

# %%
empty_set
# Out:
# {2, 33, 66, 77}

# %%
empty_set.update([33, 66, 77, 2])

# %%
empty_set
# Out:
# {2, 33, 66, 77}

# %%
empty_set.pop()
# Out:
# 33

# %%
empty_set
# Out:
# {2, 66, 77}

# %%
set1 = {2, 5, 7}

# %%
set2 = {3,4,9,5,2,6}

# %%
set1.union(set2)
# Out:
# {2, 3, 4, 5, 6, 7, 9}

# %%
set1.intersection(set2)
# Out:
# {2, 5}
