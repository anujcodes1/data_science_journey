# %%
import json

# %%
obj = {"name":"anuj", "comapny": "IBM", "salary": "120000"}
s = json.dumps(obj)
type(s)
print(s)
# Out:
# {"name": "anuj", "comapny": "IBM", "salary": "120000"}

# %%
type(s)
# Out:
# str

# %%
d = json.loads('{"name":"anuj", "comapny": "IBM", "salary": "120000"}')

# %%
type(d)
# Out:
# dict

# %%
print(d)
# Out:
# {'name': 'anuj', 'comapny': 'IBM', 'salary': '120000'}

# %%
file = open("data.json" , "w")

# %%
json.dump(obj , file)

# %%
file.close()
