# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d = {
    "name": "anuj",
      "age" :  23,
     "city": "lucknow"
}

# %%
d
# Out:
# {'name': 'anuj', 'age': 23, 'city': 'lucknow'}

# %%
d['name']
# Out:
# 'anuj'

# %%
print(d['age'])
# Out:
# 23

# %%
d['age'] = 24

# %%
print(d)
# Out:
# {'name': 'anuj', 'age': 24, 'city': 'lucknow'}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
d.values()
# Out:
# dict_values(['anuj', 24, 'lucknow'])

# %%
d.items()
# Out:
# dict_items([('name', 'anuj'), ('age', 24), ('city', 'lucknow')])

# %%
d.update({"name" : "mike" , "grade": "A" , "language": "python"})

# %%
d
# Out:
# {'name': 'mike',
#  'age': 24,
#  'city': 'lucknow',
#  'grade': 'A',
#  'language': 'python'}
