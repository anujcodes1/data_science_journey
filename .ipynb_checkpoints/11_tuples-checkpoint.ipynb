# %%
t = ()

# %%
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
t = (2 ,4, 5, 6)

# %%
t
# Out:
# (2, 4, 5, 6)

# %%
len(t)
# Out:
# 4

# %%
t
# Out:
# (2, 4, 5, 6)

# %%
t[0]
# Out:
# 2

# %%
t.count(4)
# Out:
# 1

# %%
t.count(0)
# Out:
# 0

# %%
t[0:2]
# Out:
# (2, 4)
