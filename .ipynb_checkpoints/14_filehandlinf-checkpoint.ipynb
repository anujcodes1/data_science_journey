# %%
f = open("text.txt", "r")
f.read()
# Out:
# "'Anuj Mishra will become AI engineer in 2026.'"

# %%
f.close()

# %%
s = "Anuj Mishra will become Software engineer"

# %%
f.close()

# %%
f = open('anuj.txt', "w")

# %%
f.write(s)
# Out:
# 41

# %%
f.close()

# %%
f = open(r"E:\Data Science\anuj.txt", "w")
f.write("Anuj Mishra will become Software Engineer")
f.close()

# %%
import os
os.path.exists("anuj.txt")
# Out:
# True
