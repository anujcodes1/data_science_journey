# %%
name = "Anuj"

# %%
name
# Out:
# 'Anuj'

# %%
name.upper()
# Out:
# 'ANUJ'

# %%
name.lower()
# Out:
# 'anuj'

# %%
name.capitalize()
# Out:
# 'Anuj'

# %%
name.endswith("ju")
# Out:
# False

# %%
name.endswith("uj")
# Out:
# True

# %%
name.count("j")
# Out:
# 1

# %%
a = "anuj"
len(a)
# Out:
# 4

# %%
s = "codewithAnujMishra"

# %%
s[0:6]
# Out:
# 'codewi'

# %%
s[1:-1]
# Out:
# 'odewithAnujMishr'

# %%
len(s)
# Out:
# 18

# %%
s[1:17]
# Out:
# 'odewithAnujMishr'
