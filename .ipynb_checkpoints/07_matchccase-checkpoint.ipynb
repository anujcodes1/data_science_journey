# %%
code = 500

# %%
match code:
    case 200:
        print("response ok")
    case 400:
        print("bad request")
    case 404:
        print("not found")
    case 500:
        print("internal server error")
print("end of the program")
# Out:
# internal server error
# end of the program
