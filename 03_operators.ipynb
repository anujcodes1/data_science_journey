# %%
a = 80
b = 4

# %%
a + b
a - b 
a *b
a/b
a//b
# Out:
# 20

# %%
a - b
# Out:
# 76

# %%
a*b
# Out:
# 320

# %%
a/b
# Out:
# 20.0

# %%
a//b
# Out:
# 20

# %%
a%b
# Out:
# 0

# %%
a**b
# Out:
# 40960000

# %%
a**2
# Out:
# 6400

# %%
b**2
# Out:
# 16

# %%
a  =34
b = 11

# %%
a>b
# Out:
# True

# %%
b>a
# Out:
# False

# %%
a<b
# Out:
# False

# %%
b<a
# Out:
# True

# %%
c =44.9
a == c   #checking equality , is a equal to c?
# Out:
# False

# %%
a!=c
# Out:
# True

# %%
a1 = False
b1 = True

# %%
not(b1)
# Out:
# False

# %%
not(a1)
# Out:
# True

# %%
a1 or b1
# Out:
# True

# %%
a1 and b1
# Out:
# False

# %%
c1 = True

# %%
c2 = True

# %%
c1 and c2
# Out:
# True

# %%
d1 = False
d2 = False

# %%
d1 and d2
# Out:
# False

# %%
d1 or d2
# Out:
# False
