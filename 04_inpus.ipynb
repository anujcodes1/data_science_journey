# %%
a = input("Enter the value")
# Out:
# Enter the value 40

# %%
a
# Out:
# '40'

# %%
b = input("Enter the value")
# Out:
# Enter the value 4

# %%
b
# Out:
# '4'

# %%
a + b
# Out:
# '404'

# %%
int(a) + int(b)
# Out:
# 44

# %%
a = int(input("Enter the value"))  # by default it takes user input as string
# Out:
# Enter the value 40

# %%
a
# Out:
# 40

# %%
b = int(input("Enter the value"))
# Out:
# Enter the value 9

# %%
b
# Out:
# 9

# %%
a + b
# Out:
# 49
