# %%
s = "Anujmishra"

# %%
s[2]
# Out:
# 'u'

# %%
s[2:6]
# Out:
# 'ujmi'

# %%
s.upper()
# Out:
# 'ANUJMISHRA'

# %%
s.lower()
# Out:
# 'anujmishra'

# %%
len(s)
# Out:
# 10

# %%
name  = "AnujMishra"

# %%
age = 24

# %%
print(f"my name is {name} and my age is {age}".format(name,age))
# Out:
# my name is AnujMishra and my age is 24
