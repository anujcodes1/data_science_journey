# %%
a = 32
b = 5

# %%
a + b
# Out:
# 37

# %%
name = "Anuj"

# %%
print(name)
# Out:
# Anuj

# %%
print("Hello World")
# Out:
# Hello World

# %%
# this is a jupyter notebook"

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a = "320"

# %%
b = " 420"

# %%
a + b
# Out:
# '320 420'

# %%
int(a) + int(b)  #typecasting
# Out:
# 740
